# %% [markdown]
# # The basics of Neural Circuit Policies
#
# In this tutorial we will build three recurrent neural networks based on the LTC model:
#
# *   A fully-connected network
# *   A sparse, randomly wired network
# *   A sparse, structured network based on the NCP principles
#
# ![wirings.png](https://raw.githubusercontent.com/mlech26l/keras-ncp/master/misc/wirings.png)
#
# We will train these networks on some generated time-series and compare their training performance.

# %%
# Install dependencies if they are not installed yet
# !pip install seaborn ncps
# Out:
# Requirement already satisfied: seaborn in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: ncps in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: future in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from ncps) (1.0.0)
# Requirement already satisfied: packaging in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from ncps) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
# !pip install tensorflow==2.10.0
# Out:
# Requirement already satisfied: tensorflow==2.10.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (24.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (57.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (1.66.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.34.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lcorpaci\documents\thesis\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)

# %%
import numpy as np
import os
from tensorflow import keras
from ncps import wirings
from ncps.tf import LTC
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Generating synthetic sinusoidal training data

# %%
N = 48 # Length of the time-series
# Input feature is a sine and a cosine wave
data_x = np.stack(
    [np.sin(np.linspace(0, 3 * np.pi, N)), np.cos(np.linspace(0, 3 * np.pi, N))], axis=1
)
data_x = np.expand_dims(data_x, axis=0).astype(np.float32)  # Add batch dimension
# Target output is a sine with double the frequency of the input signal
data_y = np.sin(np.linspace(0, 6 * np.pi, N)).reshape([1, N, 1]).astype(np.float32)
print("data_x.shape: ", str(data_x.shape))
print("data_y.shape: ", str(data_y.shape))

# Let's visualize the training data
sns.set()
plt.figure(figsize=(6, 4))
plt.plot(data_x[0, :, 0], label="Input feature 1")
plt.plot(data_x[0, :, 1], label="Input feature 1")
plt.plot(data_y[0, :, 0], label="Target output")
plt.ylim((-1, 1))
plt.title("Training data")
plt.legend(loc="upper right")
plt.show()
# Out:
# data_x.shape:  (1, 48, 2)
# data_y.shape:  (1, 48, 1)

# %% [markdown]
# ## The LTC model
#
# The ```ncps``` package is composed of two main parts:
#
# - The LTC model as a ```tf.keras.layers.Layer``` RNN
# - An wiring architecture for the LTC cell above
#
# The wiring could be fully-connected (all-to-all) or sparsely designed using the NCP principles introduced in the paper.
#
# Note that as the LTC model is expressed in the form of a system of [ordinary differential equations in time](https://arxiv.org/abs/2006.04439), any instance of it is inherently a recurrent neural network (RNN).
# That's why this simple example considers a sinusoidal time-series.

# %% [markdown]
# ### Our first LTC model with fully-connected wiring

# %%
fc_wiring = wirings.FullyConnected(8, 1)  # 8 units, 1 of which is a motor neuron

model = keras.models.Sequential(
    [
        keras.layers.InputLayer(input_shape=(None, 2)),
        LTC(fc_wiring, return_sequences=True),
    ]
)
model.compile(
    optimizer=keras.optimizers.Adam(0.01), loss='mean_squared_error'
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  ltc (LTC)                   (None, None, 1)           350
#
# =================================================================
# Total params: 350
# Trainable params: 350
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Draw the wiring diagram of the network

# %%
sns.set_style("white")
plt.figure(figsize=(6, 4))
legend_handles = fc_wiring.draw_graph(draw_labels=True)
plt.legend(handles=legend_handles, loc="upper center", bbox_to_anchor=(1, 1))
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualizing the prediction of the network before training

# %%
# Let's visualize how LTC initialy performs before the training
sns.set()
prediction = model(data_x).numpy()
plt.figure(figsize=(6, 4))
plt.plot(data_y[0, :, 0], label="Target output")
plt.plot(prediction[0, :, 0], label="LTC output")
plt.ylim((-1, 1))
plt.title("Before training")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Training the model

# %%
# Train the model for 400 epochs (= training steps)
hist = model.fit(x=data_x, y=data_y, batch_size=1, epochs=400,verbose=1)
# Out:
# Epoch 1/400
# 1/1 [==============================] - 7s 7s/step - loss: 0.4929
# Epoch 2/400
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4708
# Epoch 3/400
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4632
# Epoch 4/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4582
# Epoch 5/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4509
# Epoch 6/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4417
# Epoch 7/400
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4320
# Epoch 8/400
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4223
# Epoch 9/400
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4131
# Epoch 10/400
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4040
# Epoch 11/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3948
# Epoch 12/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3854
# Epoch 13/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3756
# Epoch 14/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.3654
# Epoch 15/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.3550
# Epoch 16/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.3444
# Epoch 17/400
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3336
# Epoch 18/400
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3227
# Epoch 19/400
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3114
# Epoch 20/400
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2999
# Epoch 21/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2889
# Epoch 22/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2788
# Epoch 23/400
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2686
# Epoch 24/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2578
# Epoch 25/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2468
# Epoch 26/400
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2361
# Epoch 27/400
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2255
# Epoch 28/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2148
# Epoch 29/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2049
# Epoch 30/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1954
# Epoch 31/400
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1854
# Epoch 32/400
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1758
# Epoch 33/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1663
# Epoch 34/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1566
# Epoch 35/400
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1477
# Epoch 36/400
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1390
# Epoch 37/400
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1307
# Epoch 38/400
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1217
# Epoch 39/400
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1117
# Epoch 40/400
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1009
# Epoch 41/400
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0913
# Epoch 42/400
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0835
# Epoch 43/400
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0760
# Epoch 44/400
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0675
# Epoch 45/400
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0591
# Epoch 46/400
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0519
# Epoch 47/400
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0469
# Epoch 48/400
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0426
# Epoch 49/400
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0420
# Epoch 50/400
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0544
# Epoch 51/400
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0498
# Epoch 52/400
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0453
# Epoch 53/400
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0345
# Epoch 54/400
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0481
# Epoch 55/400
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0389
# Epoch 56/400
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0295
# Epoch 57/400
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0379
# Epoch 58/400
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0328
# Epoch 59/400
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0286
# Epoch 60/400
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0246
# Epoch 61/400
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0237
# Epoch 62/400
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0271
# Epoch 63/400
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0195
# Epoch 64/400
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0188
# Epoch 65/400
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0193
# Epoch 66/400
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0179
# Epoch 67/400
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0174
# Epoch 68/400
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0135
# Epoch 69/400
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0136
# Epoch 70/400
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0143
# Epoch 71/400
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0133
# Epoch 72/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0129
# Epoch 73/400
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0111
# Epoch 74/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0110
# Epoch 75/400
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0117
# Epoch 76/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0109
# Epoch 77/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0104
# Epoch 78/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0094
# Epoch 79/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0091
# Epoch 80/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0096
# Epoch 81/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0091
# Epoch 82/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0087
# Epoch 83/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0081
# Epoch 84/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0078
# Epoch 85/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0080
# Epoch 86/400
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0075
# Epoch 87/400
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0072
# Epoch 88/400
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0067
# Epoch 89/400
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0066
# Epoch 90/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0065
# Epoch 91/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0061
# Epoch 92/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0059
# Epoch 93/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0056
# Epoch 94/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0055
# Epoch 95/400
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0053
# Epoch 96/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0050
# Epoch 97/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0048
# Epoch 98/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0046
# Epoch 99/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0044
# Epoch 100/400
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0042
# Epoch 101/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0041
# Epoch 102/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0039
# Epoch 103/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0037
# Epoch 104/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0036
# Epoch 105/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0035
# Epoch 106/400
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0033
# Epoch 107/400
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0032
# Epoch 108/400
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0031
# Epoch 109/400
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0030
# Epoch 110/400
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0028
# Epoch 111/400
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0027
# Epoch 112/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0026
# Epoch 113/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0025
# Epoch 114/400
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0024
# Epoch 115/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0023
# Epoch 116/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0022
# Epoch 117/400
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0021
# Epoch 118/400
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0020
# Epoch 119/400
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0020
# Epoch 120/400
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0019
# Epoch 121/400
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0018
# Epoch 122/400
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0018
# Epoch 123/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0017
# Epoch 124/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0016
# Epoch 125/400
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0016
# Epoch 126/400
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0015
# Epoch 127/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0015
# Epoch 128/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0014
# Epoch 129/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0014
# Epoch 130/400
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0013
# Epoch 131/400
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0013
# Epoch 132/400
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0013
# Epoch 133/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0012
# Epoch 134/400
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0012
# Epoch 135/400
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0011
# Epoch 136/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0011
# Epoch 137/400
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0011
# Epoch 138/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0011
# Epoch 139/400
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0010
# Epoch 140/400
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0010
# Epoch 141/400
# 1/1 [==============================] - 0s 79ms/step - loss: 9.8951e-04
# Epoch 142/400
# 1/1 [==============================] - 0s 86ms/step - loss: 9.6737e-04
# Epoch 143/400
# 1/1 [==============================] - 0s 75ms/step - loss: 9.4809e-04
# Epoch 144/400
# 1/1 [==============================] - 0s 63ms/step - loss: 9.2836e-04
# Epoch 145/400
# 1/1 [==============================] - 0s 70ms/step - loss: 9.1044e-04
# Epoch 146/400
# 1/1 [==============================] - 0s 68ms/step - loss: 8.9494e-04
# Epoch 147/400
# 1/1 [==============================] - 0s 72ms/step - loss: 8.7745e-04
# Epoch 148/400
# 1/1 [==============================] - 0s 65ms/step - loss: 8.6428e-04
# Epoch 149/400
# 1/1 [==============================] - 0s 64ms/step - loss: 8.4939e-04
# Epoch 150/400
# 1/1 [==============================] - 0s 62ms/step - loss: 8.3689e-04
# Epoch 151/400
# 1/1 [==============================] - 0s 62ms/step - loss: 8.2402e-04
# Epoch 152/400
# 1/1 [==============================] - 0s 61ms/step - loss: 8.1298e-04
# Epoch 153/400
# 1/1 [==============================] - 0s 61ms/step - loss: 8.0136e-04
# Epoch 154/400
# 1/1 [==============================] - 0s 61ms/step - loss: 7.9132e-04
# Epoch 155/400
# 1/1 [==============================] - 0s 56ms/step - loss: 7.8167e-04
# Epoch 156/400
# 1/1 [==============================] - 0s 58ms/step - loss: 7.7199e-04
# Epoch 157/400
# 1/1 [==============================] - 0s 58ms/step - loss: 7.6374e-04
# Epoch 158/400
# 1/1 [==============================] - 0s 56ms/step - loss: 7.5514e-04
# Epoch 159/400
# 1/1 [==============================] - 0s 59ms/step - loss: 7.4726e-04
# Epoch 160/400
# 1/1 [==============================] - 0s 55ms/step - loss: 7.3983e-04
# Epoch 161/400
# 1/1 [==============================] - 0s 57ms/step - loss: 7.3251e-04
# Epoch 162/400
# 1/1 [==============================] - 0s 61ms/step - loss: 7.2559e-04
# Epoch 163/400
# 1/1 [==============================] - 0s 60ms/step - loss: 7.1908e-04
# Epoch 164/400
# 1/1 [==============================] - 0s 67ms/step - loss: 7.1255e-04
# Epoch 165/400
# 1/1 [==============================] - 0s 58ms/step - loss: 7.0651e-04
# Epoch 166/400
# 1/1 [==============================] - 0s 63ms/step - loss: 7.0049e-04
# Epoch 167/400
# 1/1 [==============================] - 0s 58ms/step - loss: 6.9472e-04
# Epoch 168/400
# 1/1 [==============================] - 0s 104ms/step - loss: 6.8908e-04
# Epoch 169/400
# 1/1 [==============================] - 0s 66ms/step - loss: 6.8359e-04
# Epoch 170/400
# 1/1 [==============================] - 0s 58ms/step - loss: 6.7824e-04
# Epoch 171/400
# 1/1 [==============================] - 0s 55ms/step - loss: 6.7300e-04
# Epoch 172/400
# 1/1 [==============================] - 0s 59ms/step - loss: 6.6788e-04
# Epoch 173/400
# 1/1 [==============================] - 0s 55ms/step - loss: 6.6284e-04
# Epoch 174/400
# 1/1 [==============================] - 0s 56ms/step - loss: 6.5793e-04
# Epoch 175/400
# 1/1 [==============================] - 0s 62ms/step - loss: 6.5304e-04
# Epoch 176/400
# 1/1 [==============================] - 0s 57ms/step - loss: 6.4831e-04
# Epoch 177/400
# 1/1 [==============================] - 0s 57ms/step - loss: 6.4356e-04
# Epoch 178/400
# 1/1 [==============================] - 0s 59ms/step - loss: 6.3896e-04
# Epoch 179/400
# 1/1 [==============================] - 0s 57ms/step - loss: 6.3437e-04
# Epoch 180/400
# 1/1 [==============================] - 0s 69ms/step - loss: 6.2988e-04
# Epoch 181/400
# 1/1 [==============================] - 0s 58ms/step - loss: 6.2541e-04
# Epoch 182/400
# 1/1 [==============================] - 0s 59ms/step - loss: 6.2105e-04
# Epoch 183/400
# 1/1 [==============================] - 0s 58ms/step - loss: 6.1666e-04
# Epoch 184/400
# 1/1 [==============================] - 0s 56ms/step - loss: 6.1239e-04
# Epoch 185/400
# 1/1 [==============================] - 0s 60ms/step - loss: 6.0815e-04
# Epoch 186/400
# 1/1 [==============================] - 0s 67ms/step - loss: 6.0393e-04
# Epoch 187/400
# 1/1 [==============================] - 0s 62ms/step - loss: 5.9981e-04
# Epoch 188/400
# 1/1 [==============================] - 0s 64ms/step - loss: 5.9570e-04
# Epoch 189/400
# 1/1 [==============================] - 0s 58ms/step - loss: 5.9165e-04
# Epoch 190/400
# 1/1 [==============================] - 0s 55ms/step - loss: 5.8764e-04
# Epoch 191/400
# 1/1 [==============================] - 0s 62ms/step - loss: 5.8368e-04
# Epoch 192/400
# 1/1 [==============================] - 0s 66ms/step - loss: 5.7975e-04
# Epoch 193/400
# 1/1 [==============================] - 0s 73ms/step - loss: 5.7587e-04
# Epoch 194/400
# 1/1 [==============================] - 0s 75ms/step - loss: 5.7204e-04
# Epoch 195/400
# 1/1 [==============================] - 0s 64ms/step - loss: 5.6823e-04
# Epoch 196/400
# 1/1 [==============================] - 0s 64ms/step - loss: 5.6447e-04
# Epoch 197/400
# 1/1 [==============================] - 0s 66ms/step - loss: 5.6074e-04
# Epoch 198/400
# 1/1 [==============================] - 0s 56ms/step - loss: 5.5707e-04
# Epoch 199/400
# 1/1 [==============================] - 0s 56ms/step - loss: 5.5341e-04
# Epoch 200/400
# 1/1 [==============================] - 0s 54ms/step - loss: 5.4980e-04
# Epoch 201/400
# 1/1 [==============================] - 0s 55ms/step - loss: 5.4622e-04
# Epoch 202/400
# 1/1 [==============================] - 0s 56ms/step - loss: 5.4267e-04
# Epoch 203/400
# 1/1 [==============================] - 0s 52ms/step - loss: 5.3917e-04
# Epoch 204/400
# 1/1 [==============================] - 0s 58ms/step - loss: 5.3568e-04
# Epoch 205/400
# 1/1 [==============================] - 0s 52ms/step - loss: 5.3224e-04
# Epoch 206/400
# 1/1 [==============================] - 0s 55ms/step - loss: 5.2882e-04
# Epoch 207/400
# 1/1 [==============================] - 0s 53ms/step - loss: 5.2543e-04
# Epoch 208/400
# 1/1 [==============================] - 0s 54ms/step - loss: 5.2208e-04
# Epoch 209/400
# 1/1 [==============================] - 0s 60ms/step - loss: 5.1875e-04
# Epoch 210/400
# 1/1 [==============================] - 0s 64ms/step - loss: 5.1546e-04
# Epoch 211/400
# 1/1 [==============================] - 0s 79ms/step - loss: 5.1219e-04
# Epoch 212/400
# 1/1 [==============================] - 0s 81ms/step - loss: 5.0894e-04
# Epoch 213/400
# 1/1 [==============================] - 0s 81ms/step - loss: 5.0573e-04
# Epoch 214/400
# 1/1 [==============================] - 0s 76ms/step - loss: 5.0253e-04
# Epoch 215/400
# 1/1 [==============================] - 0s 75ms/step - loss: 4.9937e-04
# Epoch 216/400
# 1/1 [==============================] - 0s 82ms/step - loss: 4.9622e-04
# Epoch 217/400
# 1/1 [==============================] - 0s 88ms/step - loss: 4.9311e-04
# Epoch 218/400
# 1/1 [==============================] - 0s 78ms/step - loss: 4.9001e-04
# Epoch 219/400
# 1/1 [==============================] - 0s 80ms/step - loss: 4.8694e-04
# Epoch 220/400
# 1/1 [==============================] - 0s 74ms/step - loss: 4.8389e-04
# Epoch 221/400
# 1/1 [==============================] - 0s 82ms/step - loss: 4.8086e-04
# Epoch 222/400
# 1/1 [==============================] - 0s 89ms/step - loss: 4.7786e-04
# Epoch 223/400
# 1/1 [==============================] - 0s 85ms/step - loss: 4.7488e-04
# Epoch 224/400
# 1/1 [==============================] - 0s 148ms/step - loss: 4.7191e-04
# Epoch 225/400
# 1/1 [==============================] - 0s 83ms/step - loss: 4.6897e-04
# Epoch 226/400
# 1/1 [==============================] - 0s 83ms/step - loss: 4.6604e-04
# Epoch 227/400
# 1/1 [==============================] - 0s 89ms/step - loss: 4.6313e-04
# Epoch 228/400
# 1/1 [==============================] - 0s 87ms/step - loss: 4.6025e-04
# Epoch 229/400
# 1/1 [==============================] - 0s 85ms/step - loss: 4.5738e-04
# Epoch 230/400
# 1/1 [==============================] - 0s 81ms/step - loss: 4.5453e-04
# Epoch 231/400
# 1/1 [==============================] - 0s 84ms/step - loss: 4.5170e-04
# Epoch 232/400
# 1/1 [==============================] - 0s 87ms/step - loss: 4.4888e-04
# Epoch 233/400
# 1/1 [==============================] - 0s 89ms/step - loss: 4.4609e-04
# Epoch 234/400
# 1/1 [==============================] - 0s 96ms/step - loss: 4.4331e-04
# Epoch 235/400
# 1/1 [==============================] - 0s 97ms/step - loss: 4.4054e-04
# Epoch 236/400
# 1/1 [==============================] - 0s 96ms/step - loss: 4.3780e-04
# Epoch 237/400
# 1/1 [==============================] - 0s 95ms/step - loss: 4.3507e-04
# Epoch 238/400
# 1/1 [==============================] - 0s 95ms/step - loss: 4.3236e-04
# Epoch 239/400
# 1/1 [==============================] - 0s 89ms/step - loss: 4.2966e-04
# Epoch 240/400
# 1/1 [==============================] - 0s 79ms/step - loss: 4.2698e-04
# Epoch 241/400
# 1/1 [==============================] - 0s 88ms/step - loss: 4.2431e-04
# Epoch 242/400
# 1/1 [==============================] - 0s 109ms/step - loss: 4.2166e-04
# Epoch 243/400
# 1/1 [==============================] - 0s 126ms/step - loss: 4.1902e-04
# Epoch 244/400
# 1/1 [==============================] - 0s 157ms/step - loss: 4.1640e-04
# Epoch 245/400
# 1/1 [==============================] - 0s 94ms/step - loss: 4.1379e-04
# Epoch 246/400
# 1/1 [==============================] - 0s 96ms/step - loss: 4.1120e-04
# Epoch 247/400
# 1/1 [==============================] - 0s 98ms/step - loss: 4.0864e-04
# Epoch 248/400
# 1/1 [==============================] - 0s 101ms/step - loss: 4.0609e-04
# Epoch 249/400
# 1/1 [==============================] - 0s 99ms/step - loss: 4.0360e-04
# Epoch 250/400
# 1/1 [==============================] - 0s 126ms/step - loss: 4.0121e-04
# Epoch 251/400
# 1/1 [==============================] - 0s 111ms/step - loss: 3.9912e-04
# Epoch 252/400
# 1/1 [==============================] - 0s 120ms/step - loss: 3.9793e-04
# Epoch 253/400
# 1/1 [==============================] - 0s 100ms/step - loss: 3.9933e-04
# Epoch 254/400
# 1/1 [==============================] - 0s 133ms/step - loss: 4.0949e-04
# Epoch 255/400
# 1/1 [==============================] - 0s 96ms/step - loss: 4.4034e-04
# Epoch 256/400
# 1/1 [==============================] - 0s 97ms/step - loss: 5.2679e-04
# Epoch 257/400
# 1/1 [==============================] - 0s 95ms/step - loss: 5.8318e-04
# Epoch 258/400
# 1/1 [==============================] - 0s 102ms/step - loss: 5.8125e-04
# Epoch 259/400
# 1/1 [==============================] - 0s 91ms/step - loss: 4.4290e-04
# Epoch 260/400
# 1/1 [==============================] - 0s 90ms/step - loss: 4.0273e-04
# Epoch 261/400
# 1/1 [==============================] - 0s 91ms/step - loss: 4.5885e-04
# Epoch 262/400
# 1/1 [==============================] - 0s 92ms/step - loss: 5.0087e-04
# Epoch 263/400
# 1/1 [==============================] - 0s 93ms/step - loss: 4.4220e-04
# Epoch 264/400
# 1/1 [==============================] - 0s 88ms/step - loss: 3.6976e-04
# Epoch 265/400
# 1/1 [==============================] - 0s 90ms/step - loss: 4.1479e-04
# Epoch 266/400
# 1/1 [==============================] - 0s 90ms/step - loss: 4.5088e-04
# Epoch 267/400
# 1/1 [==============================] - 0s 90ms/step - loss: 4.0772e-04
# Epoch 268/400
# 1/1 [==============================] - 0s 96ms/step - loss: 3.7311e-04
# Epoch 269/400
# 1/1 [==============================] - 0s 93ms/step - loss: 3.7752e-04
# Epoch 270/400
# 1/1 [==============================] - 0s 90ms/step - loss: 4.0730e-04
# Epoch 271/400
# 1/1 [==============================] - 0s 93ms/step - loss: 4.0544e-04
# Epoch 272/400
# 1/1 [==============================] - 0s 184ms/step - loss: 3.5758e-04
# Epoch 273/400
# 1/1 [==============================] - 0s 86ms/step - loss: 3.6066e-04
# Epoch 274/400
# 1/1 [==============================] - 0s 90ms/step - loss: 3.8543e-04
# Epoch 275/400
# 1/1 [==============================] - 0s 89ms/step - loss: 3.7588e-04
# Epoch 276/400
# 1/1 [==============================] - 0s 92ms/step - loss: 3.5843e-04
# Epoch 277/400
# 1/1 [==============================] - 0s 87ms/step - loss: 3.4472e-04
# Epoch 278/400
# 1/1 [==============================] - 0s 89ms/step - loss: 3.5417e-04
# Epoch 279/400
# 1/1 [==============================] - 0s 84ms/step - loss: 3.6456e-04
# Epoch 280/400
# 1/1 [==============================] - 0s 81ms/step - loss: 3.4679e-04
# Epoch 281/400
# 1/1 [==============================] - 0s 71ms/step - loss: 3.3448e-04
# Epoch 282/400
# 1/1 [==============================] - 0s 74ms/step - loss: 3.3891e-04
# Epoch 283/400
# 1/1 [==============================] - 0s 76ms/step - loss: 3.4184e-04
# Epoch 284/400
# 1/1 [==============================] - 0s 63ms/step - loss: 3.4076e-04
# Epoch 285/400
# 1/1 [==============================] - 0s 70ms/step - loss: 3.3018e-04
# Epoch 286/400
# 1/1 [==============================] - 0s 63ms/step - loss: 3.2204e-04
# Epoch 287/400
# 1/1 [==============================] - 0s 60ms/step - loss: 3.2675e-04
# Epoch 288/400
# 1/1 [==============================] - 0s 60ms/step - loss: 3.2850e-04
# Epoch 289/400
# 1/1 [==============================] - 0s 60ms/step - loss: 3.2253e-04
# Epoch 290/400
# 1/1 [==============================] - 0s 62ms/step - loss: 3.1680e-04
# Epoch 291/400
# 1/1 [==============================] - 0s 58ms/step - loss: 3.1322e-04
# Epoch 292/400
# 1/1 [==============================] - 0s 61ms/step - loss: 3.1336e-04
# Epoch 293/400
# 1/1 [==============================] - 0s 60ms/step - loss: 3.1496e-04
# Epoch 294/400
# 1/1 [==============================] - 0s 62ms/step - loss: 3.1118e-04
# Epoch 295/400
# 1/1 [==============================] - 0s 61ms/step - loss: 3.0534e-04
# Epoch 296/400
# 1/1 [==============================] - 0s 64ms/step - loss: 3.0306e-04
# Epoch 297/400
# 1/1 [==============================] - 0s 59ms/step - loss: 3.0231e-04
# Epoch 298/400
# 1/1 [==============================] - 0s 61ms/step - loss: 3.0158e-04
# Epoch 299/400
# 1/1 [==============================] - 0s 59ms/step - loss: 3.0043e-04
# Epoch 300/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.9686e-04
# Epoch 301/400
# 1/1 [==============================] - 0s 66ms/step - loss: 2.9294e-04
# Epoch 302/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.9126e-04
# Epoch 303/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.9048e-04
# Epoch 304/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.8916e-04
# Epoch 305/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.8745e-04
# Epoch 306/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.8497e-04
# Epoch 307/400
# 1/1 [==============================] - 0s 61ms/step - loss: 2.8197e-04
# Epoch 308/400
# 1/1 [==============================] - 0s 68ms/step - loss: 2.7983e-04
# Epoch 309/400
# 1/1 [==============================] - 0s 63ms/step - loss: 2.7858e-04
# Epoch 310/400
# 1/1 [==============================] - 0s 66ms/step - loss: 2.7721e-04
# Epoch 311/400
# 1/1 [==============================] - 0s 66ms/step - loss: 2.7562e-04
# Epoch 312/400
# 1/1 [==============================] - 0s 66ms/step - loss: 2.7392e-04
# Epoch 313/400
# 1/1 [==============================] - 0s 72ms/step - loss: 2.7182e-04
# Epoch 314/400
# 1/1 [==============================] - 0s 86ms/step - loss: 2.6945e-04
# Epoch 315/400
# 1/1 [==============================] - 0s 136ms/step - loss: 2.6745e-04
# Epoch 316/400
# 1/1 [==============================] - 0s 61ms/step - loss: 2.6579e-04
# Epoch 317/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.6417e-04
# Epoch 318/400
# 1/1 [==============================] - 0s 61ms/step - loss: 2.6264e-04
# Epoch 319/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.6120e-04
# Epoch 320/400
# 1/1 [==============================] - 0s 61ms/step - loss: 2.5963e-04
# Epoch 321/400
# 1/1 [==============================] - 0s 65ms/step - loss: 2.5784e-04
# Epoch 322/400
# 1/1 [==============================] - 0s 65ms/step - loss: 2.5605e-04
# Epoch 323/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.5429e-04
# Epoch 324/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.5250e-04
# Epoch 325/400
# 1/1 [==============================] - 0s 76ms/step - loss: 2.5067e-04
# Epoch 326/400
# 1/1 [==============================] - 0s 78ms/step - loss: 2.4895e-04
# Epoch 327/400
# 1/1 [==============================] - 0s 63ms/step - loss: 2.4730e-04
# Epoch 328/400
# 1/1 [==============================] - 0s 61ms/step - loss: 2.4565e-04
# Epoch 329/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.4400e-04
# Epoch 330/400
# 1/1 [==============================] - 0s 59ms/step - loss: 2.4241e-04
# Epoch 331/400
# 1/1 [==============================] - 0s 64ms/step - loss: 2.4087e-04
# Epoch 332/400
# 1/1 [==============================] - 0s 69ms/step - loss: 2.3932e-04
# Epoch 333/400
# 1/1 [==============================] - 0s 61ms/step - loss: 2.3778e-04
# Epoch 334/400
# 1/1 [==============================] - 0s 59ms/step - loss: 2.3629e-04
# Epoch 335/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.3487e-04
# Epoch 336/400
# 1/1 [==============================] - 0s 68ms/step - loss: 2.3353e-04
# Epoch 337/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.3234e-04
# Epoch 338/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.3143e-04
# Epoch 339/400
# 1/1 [==============================] - 0s 63ms/step - loss: 2.3108e-04
# Epoch 340/400
# 1/1 [==============================] - 0s 69ms/step - loss: 2.3177e-04
# Epoch 341/400
# 1/1 [==============================] - 0s 67ms/step - loss: 2.3465e-04
# Epoch 342/400
# 1/1 [==============================] - 0s 66ms/step - loss: 2.4167e-04
# Epoch 343/400
# 1/1 [==============================] - 0s 61ms/step - loss: 2.5814e-04
# Epoch 344/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.9020e-04
# Epoch 345/400
# 1/1 [==============================] - 0s 60ms/step - loss: 3.5943e-04
# Epoch 346/400
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6559e-04
# Epoch 347/400
# 1/1 [==============================] - 0s 63ms/step - loss: 6.4856e-04
# Epoch 348/400
# 1/1 [==============================] - 0s 69ms/step - loss: 8.2949e-04
# Epoch 349/400
# 1/1 [==============================] - 0s 69ms/step - loss: 9.7498e-04
# Epoch 350/400
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0010
# Epoch 351/400
# 1/1 [==============================] - 0s 61ms/step - loss: 8.1729e-04
# Epoch 352/400
# 1/1 [==============================] - 0s 63ms/step - loss: 5.0157e-04
# Epoch 353/400
# 1/1 [==============================] - 0s 63ms/step - loss: 2.5396e-04
# Epoch 354/400
# 1/1 [==============================] - 0s 112ms/step - loss: 2.4046e-04
# Epoch 355/400
# 1/1 [==============================] - 0s 65ms/step - loss: 4.0057e-04
# Epoch 356/400
# 1/1 [==============================] - 0s 64ms/step - loss: 5.4801e-04
# Epoch 357/400
# 1/1 [==============================] - 0s 60ms/step - loss: 5.4709e-04
# Epoch 358/400
# 1/1 [==============================] - 0s 58ms/step - loss: 3.8071e-04
# Epoch 359/400
# 1/1 [==============================] - 0s 58ms/step - loss: 2.3380e-04
# Epoch 360/400
# 1/1 [==============================] - 0s 59ms/step - loss: 2.1697e-04
# Epoch 361/400
# 1/1 [==============================] - 0s 55ms/step - loss: 3.0645e-04
# Epoch 362/400
# 1/1 [==============================] - 0s 61ms/step - loss: 3.9091e-04
# Epoch 363/400
# 1/1 [==============================] - 0s 60ms/step - loss: 3.6447e-04
# Epoch 364/400
# 1/1 [==============================] - 0s 56ms/step - loss: 2.7122e-04
# Epoch 365/400
# 1/1 [==============================] - 0s 59ms/step - loss: 2.0277e-04
# Epoch 366/400
# 1/1 [==============================] - 0s 55ms/step - loss: 2.1476e-04
# Epoch 367/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.7061e-04
# Epoch 368/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.9952e-04
# Epoch 369/400
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7267e-04
# Epoch 370/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.1698e-04
# Epoch 371/400
# 1/1 [==============================] - 0s 75ms/step - loss: 1.9025e-04
# Epoch 372/400
# 1/1 [==============================] - 0s 66ms/step - loss: 2.0711e-04
# Epoch 373/400
# 1/1 [==============================] - 0s 63ms/step - loss: 2.3689e-04
# Epoch 374/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.4662e-04
# Epoch 375/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.2544e-04
# Epoch 376/400
# 1/1 [==============================] - 0s 66ms/step - loss: 1.9583e-04
# Epoch 377/400
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8327e-04
# Epoch 378/400
# 1/1 [==============================] - 0s 57ms/step - loss: 1.9332e-04
# Epoch 379/400
# 1/1 [==============================] - 0s 58ms/step - loss: 2.0921e-04
# Epoch 380/400
# 1/1 [==============================] - 0s 60ms/step - loss: 2.1350e-04
# Epoch 381/400
# 1/1 [==============================] - 0s 62ms/step - loss: 2.0378e-04
# Epoch 382/400
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8734e-04
# Epoch 383/400
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7692e-04
# Epoch 384/400
# 1/1 [==============================] - 0s 70ms/step - loss: 1.7820e-04
# Epoch 385/400
# 1/1 [==============================] - 0s 61ms/step - loss: 1.8592e-04
# Epoch 386/400
# 1/1 [==============================] - 0s 66ms/step - loss: 1.9146e-04
# Epoch 387/400
# 1/1 [==============================] - 0s 61ms/step - loss: 1.9011e-04
# Epoch 388/400
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8314e-04
# Epoch 389/400
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7445e-04
# Epoch 390/400
# 1/1 [==============================] - 0s 63ms/step - loss: 1.6922e-04
# Epoch 391/400
# 1/1 [==============================] - 0s 102ms/step - loss: 1.6907e-04
# Epoch 392/400
# 1/1 [==============================] - 0s 68ms/step - loss: 1.7186e-04
# Epoch 393/400
# 1/1 [==============================] - 0s 64ms/step - loss: 1.7458e-04
# Epoch 394/400
# 1/1 [==============================] - 0s 62ms/step - loss: 1.7507e-04
# Epoch 395/400
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7284e-04
# Epoch 396/400
# 1/1 [==============================] - 0s 58ms/step - loss: 1.6861e-04
# Epoch 397/400
# 1/1 [==============================] - 0s 58ms/step - loss: 1.6430e-04
# Epoch 398/400
# 1/1 [==============================] - 0s 65ms/step - loss: 1.6129e-04
# Epoch 399/400
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5991e-04
# Epoch 400/400
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5983e-04

# %% [markdown]
# ### Plotting the training loss

# %%
# Let's visualize the training loss
sns.set()
plt.figure(figsize=(6, 4))
plt.plot(hist.history["loss"], label="Training loss")
plt.legend(loc="upper right")
plt.xlabel("Training steps")
plt.show()

# %% [markdown]
# ### Plotting the prediction of the trained model

# %%
# How does the trained model now fit to the sinusoidal function?
prediction = model(data_x).numpy()
plt.figure(figsize=(6, 4))
plt.plot(data_y[0, :, 0], label="Target output")
plt.plot(prediction[0, :, 0], label="LTC output",linestyle="dashed")
plt.ylim((-1, 1))
plt.legend(loc="upper right")
plt.title("After training")
plt.show()

# %% [markdown]
# ## Other wiring architectures
#
# Next, let's see how we can define other wiring architectures and compare them to the fully-connected network above

# %% [markdown]
# ### Random network with 75% sparsity
#
# Let's create a randomly wired network where 75% of all synapses are removed.

# %%
# Define LTC cell and wiring architecture
rnd_wiring = wirings.Random(8, 1,sparsity_level=0.75)  # 8 units, 1 motor neuron

# Define Keras model
sparse_model = keras.models.Sequential(
    [
        keras.layers.InputLayer(input_shape=(None, 2)),
        LTC(rnd_wiring, return_sequences=True),
    ]
)
sparse_model.compile(
    optimizer=keras.optimizers.Adam(0.01), loss='mean_squared_error'
)

# Plot the wiring
sns.set_style("white")
plt.figure(figsize=(6, 4))
legend_handles = rnd_wiring.draw_graph(draw_labels=True)
plt.legend(handles=legend_handles, loc="upper center", bbox_to_anchor=(1, 1))
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparing random sparse vs fully-connected networks

# %%
hist_rand = sparse_model.fit(x=data_x, y=data_y, batch_size=1, epochs=400,verbose=0)
# This may take a while (training the sprase LTC model)
sns.set()
plt.figure(figsize=(6, 4))
plt.plot(hist.history["loss"], label="Fully-connected")
plt.plot(hist_rand.history["loss"], label="Random (75% sparsity)")
plt.legend(loc="upper right")
plt.xlabel("Training steps")
plt.ylabel("Training loss")
plt.show()

# %% [markdown]
# We see that the sparse model is not able to fit the sinusoidal signal as perfectly as the fully-connected architecture.
#
# ### Neural Circuit Policy wiring architecture

# %%
ncp_arch = wirings.AutoNCP(8,1)

ncp_model = keras.models.Sequential(
    [
        keras.layers.InputLayer(input_shape=(None, 2)),
        LTC(ncp_arch, return_sequences=True),
    ]
)
ncp_model.compile(
    optimizer=keras.optimizers.Adam(0.01), loss='mean_squared_error'
)
sns.set_style("white")
plt.figure(figsize=(6, 4))
legend_handles = ncp_arch.draw_graph(draw_labels=True, neuron_colors={"command": "tab:cyan"})
plt.legend(handles=legend_handles, loc="upper center", bbox_to_anchor=(1.1, 1.1))
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %%
hist_ncp = ncp_model.fit(x=data_x, y=data_y, batch_size=1, epochs=400,verbose=0)
# This may take a while (training the LTC model)
sns.set()
plt.figure(figsize=(6, 4))
plt.plot(hist.history["loss"], label="Fully-connected")
plt.plot(hist_rand.history["loss"], label="Random (75% sparsity)")
plt.plot(hist_ncp.history["loss"], label="NCP")
plt.legend(loc="upper right")
plt.xlabel("Training steps")
plt.ylabel("Training loss")
plt.show()

# %% [markdown]
# We see that the network with the NCP wiring architecture could fit the data as close as the fully-connected model.
#
# ### Computing the sparsity of a NCP network

# %%
# Let's compare how many synapses the NCP network has compared to the fully-connected one
sparsity = 1 - ncp_arch.synapse_count /fc_wiring.synapse_count
print("Sparsity level is {:0.2f}%".format(100*sparsity))
# Out:
# Sparsity level is 82.81%

# %% [markdown]
# The network with the NCP wiring performs as good as the fully-connected network but is even sparser than our random network tested above.
